# %%
import numpy as np

a = np.array([1, 2, 3])
b = np.array([[1, 2], [3, 4]])
zeros = np.zeros((2, 3))
ones = np.ones((3, 2))
ranged = np.arange(0, 10, 2)
spaced = np.linspace(0, 1, 5)

print("a:", a, "| shape:", a.shape, "ndim:", a.ndim, "dtype:", a.dtype)
print("b:\n", b, "\nshape:", b.shape, "ndim:", b.ndim, "size:", b.size)
print("zeros:", zeros, "| shape:", zeros.shape, "ndim:", zeros.ndim, "dtype:", zeros.dtype)
#print("b:\n", b, "\nshape:", b.shape, "ndim:", b.ndim, "size:", b.size)
# Out:
# a: [1 2 3] | shape: (3,) ndim: 1 dtype: int64
# b:
#  [[1 2]
#  [3 4]]
# shape: (2, 2) ndim: 2 size: 4
# zeros: [[0. 0. 0.]
#  [0. 0. 0.]] | shape: (2, 3) ndim: 2 dtype: float64
