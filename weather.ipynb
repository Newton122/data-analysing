# %%
import pandas as pd


data = {
    'Date':['2025-08-01', 2025-08-02','2025-08-01', 2025-08-02','2025-08-01', 2025-08-02']
     'City':['Nairobi','Harare','Cairo','London','Bulawayo','Maputo','Pretoria']
     'Temperature'=[25]       
}
