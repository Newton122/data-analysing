# %%
import pandas as pd

data = {
    'ID':[1,2,3],
    'Name':['Newton','Alice','Bob'],
    'Math':[90, 80, 70],
    'Science':[85, 75, 65],
    'English':[88, 78, 68]
    
}
df = pd.DataFrame(data)
print(df)

df.to_csv('student_data.csv', index=False)
# Out:
#    ID    Name  Math  Science  English
# 0   1  Newton    90       85       88
# 1   2   Alice    80       75       78
# 2   3     Bob    70       65       68
